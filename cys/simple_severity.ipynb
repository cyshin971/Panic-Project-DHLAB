# %%
import pandas as pd

from pycaret.classification import *

# %%
DATA_PATH = "../_data/all_data_with_severity.csv"

# %%
raw_data = pd.read_csv(DATA_PATH)
print("RAW data shape:", raw_data.shape)
display(raw_data.head(5))
print("Number of data points:", len(raw_data))
# Out:
# RAW data shape: (26403, 66)
#            ID        date  panic  gender   age  PHQ_9  STAI_X2   CSM  CTQ_1  \
# 0  PXPN_10006  2024-11-04    0.0     0.0  32.0    0.0     32.0  31.0   11.0
# 1  PXPN_10006  2024-11-05    0.0     0.0  32.0    0.0     32.0  31.0   11.0
# 2  PXPN_10006  2024-11-06    1.0     0.0  32.0    0.0     32.0  31.0   11.0
# 3  PXPN_10006  2024-11-07    2.0     0.0  32.0    0.0     32.0  31.0   11.0
# 4  PXPN_10006  2024-11-08    0.0     0.0  32.0    0.0     32.0  31.0   11.0
#
#    CTQ_2  ...  medication_in_month    steps  SLT1      SLT2      SLT3  \
# 0   13.0  ...                  NaN   3770.0   NaN       NaN       NaN
# 1   13.0  ...                  NaN   4542.0   0.0  4.466667  3.616667
# 2   13.0  ...                  NaN   5119.0   0.0  0.000000  0.200000
# 3   13.0  ...                  NaN  12455.0   0.0  0.000000  0.141667
# 4   13.0  ...                  NaN   8441.0   NaN       NaN       NaN
#
#        SLT4   SLT5      SLT6  total_sleep  severity
# ...

# %%
target_col = "severity"
# filter out rows with NaN in the target column
data = raw_data[raw_data[target_col].notna()]
print("Number of data points:", len(data))
# Out:
# Number of data points: 811

# %%
s = setup(data, target = target_col)
# Out:
# <style type="text/css">
# #T_e5a51_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e5a51">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e5a51_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e5a51_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5a51_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e5a51_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e5a51_row0_col1" class="data row0 col1" >7581</td>
#     </tr>
#     <tr>
#       <th id="T_e5a51_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e5a51_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e5a51_row1_col1" class="data row1 col1" >severity</td>
#     </tr>
#     <tr>
#       <th id="T_e5a51_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         17:25:59
# Status                    Fitting 10 Folds
# Estimator  Light Gradient Boosting Machine
# <style type="text/css">
# #T_49745 th {
#   text-align: left;
# }
# ...
